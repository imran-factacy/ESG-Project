# %%
import os
import numpy as np
import pandas as pd
import pathlib

# %% [markdown]
# ## Dict

# %%
# Reading the single file which has Question and principles
ques = pd.read_excel(r"C:\Users\Dell\Desktop\esg_q_principle.xlsx")

# %%
ques
# Out:
#                                           Element Name   Principles
# 0                              CorporateIdentityNumber          NaN
# 1                                     NameOfTheCompany          NaN
# 2                                  YearOfIncorporation          NaN
# 3                   AddressOfRegisteredOfficeOfCompany          NaN
# 4                    AddressOfCorporateOfficeOfCompany          NaN
# ..                                                 ...          ...
# 509                  RemarksOnApprovalByAuditCommittee  Principle 9
# 510  AmountOfRelatedPartyTransactionDuringTheReport...  Principle 9
# 511                    AmountOfRelatedPartyTransaction  Principle 9
# 512              DetailsOfOtherRelatedPartyTransaction  Principle 9
# 513                 RelatedPartyTransactionExplanatory  Principle 9
#
# [514 rows x 2 columns]

# %%
# classifying All the questions in ESG (Environment, Social, Governance) category based on Principles
category = ques['Principles'].apply(lambda x: 'Environment' if (x == "Principle 2" or x=="Principle 6") else x)
category = category.apply(lambda x: 'Social' if (x == "Principle 3" or x=="Principle 4" or x=="Principle 5") else x)
category = category.apply(lambda x: 'Governance' if (x == "Principle 1" or x=="Principle 7" or x=="Principle 8" or x=="Principle 9") else x)
ques["esg_category"] = category

# %%
ques[190:]
# Out:
#                                           Element Name   Principles
# 190  DoesTheEntityProvideTransitionAssistanceProgra...  Principle 3  \
# 191  PercentageOfHealthAndSafetyPracticesOfValueCha...  Principle 4
# 192  PercentageOfWorkingConditionsOfValueChainPartn...  Principle 4
# 193  DetailsOfAnyCorrectiveActionTakenOrUnderwayToA...  Principle 4
# 194  DescribeTheProcessesForIdentifyingKeyStakehold...  Principle 4
# ..                                                 ...          ...
# 509                  RemarksOnApprovalByAuditCommittee  Principle 9
# 510  AmountOfRelatedPartyTransactionDuringTheReport...  Principle 9
# 511                    AmountOfRelatedPartyTransaction  Principle 9
# 512              DetailsOfOtherRelatedPartyTransaction  Principle 9
# 513                 RelatedPartyTransactionExplanatory  Principle 9
#
#     esg_category
# 190       Social
# 191       Social
# 192       Social
# 193       Social
# 194       Social
# ..           ...
# 509   Governance
# 510   Governance
# 511   Governance
# 512   Governance
# 513   Governance
#
# [324 rows x 3 columns]

# %%
# map element name to category through dictionary
ques_non_null = ques.dropna()# 120 were null hence removed while making the dictionary

dc_ques_category = {}
for element, category, principle in zip(ques_non_null["Element Name"].str.lower(), ques_non_null["esg_category"], ques_non_null["Principles"]):
    dc_ques_category[element] = [principle, category]

# %%
dc_ques_category   # this dictionary contains questions as key and esg category as value
# Out:
# {'percentageofrandd': ['Principle 2', 'Environment'],
#  'detailsofimprovementsinenvironmentalandsocialimpactsduetorandd': ['Principle 2',
#   'Environment'],
#  'percentageofcapex': ['Principle 2', 'Environment'],
#  'detailsofimprovementsinenvironmentalandsocialimpactsduetocapex': ['Principle 2',
#   'Environment'],
#  'doestheentityhaveproceduresinplaceforsustainablesourcing': ['Principle 2',
#   'Environment'],
#  'describetheprocessesinplacetosafelyreclaimyourproductsforreusingrecyclinganddisposingattheendoflifeforplasticsincludingpackagingexplanatorytextblock': ['Principle 2',
#   'Environment'],
#  'describetheprocessesinplacetosafelyreclaimyourproductsforreusingrecyclinganddisposingattheendoflifeforewasteexplanatorytextblock': ['Principle 2',
#   'Environment'],
#  'describetheprocessesinplacetosafelyreclaimyourproductsforreusingrecyclinganddisposingattheendoflifeforhazardouswasteexplanatorytextblock': ['Principle 2',
#   'Environment'],
#  'describetheprocessesinplacetosafelyreclaimyourproductsforreusingrecyclinganddisposingattheendoflifeforotherwasteexplanatorytextblock': ['Principle 2',
#   'Environment'],
#  'whetherextendedproducerresponsibilityisapplicabletotheentitysactivities': ['Principle 2',
#   'Environment'],
#  'whetherthewastecollectionplanisinlinewiththeextendedproducerresponsibilityplansubmittedtopollutioncontrolboards': ['Principle 2',
#   'Environment'],
#  'stepstakentoaddressthewastecollectionplanexplanatorytextblock': ['Principle 2',
#   'Environment'],
#  'hastheentityconductedlifecycleperspectiveorassessmentsforanyofitsproductsorforitsservices': ['Principle 2',
#   'Environment'],
#  'nameofproductorservice': ['Principle 2', 'Environment'],
#  'descriptionoftheriskorconcern': ['Principle 2', 'Environment'],
#  'actiontaken': ['Principle 2', 'Environment'],
#  'indicateinputmaterial': ['Principle 2', 'Environment'],
#  'recycledorreusedinputmaterialtototalmaterial': ['Principle 2',
#   'Environment'],
#  'amountofreused': ['Principle 2', 'Environment'],
#  'amountofrecycled': ['Principle 2', 'Environment'],
#  'amountofsafelydisposed': ['Principle 2', 'Environment'],
#  'indicateproductcategory': ['Principle 2', 'Environment'],
#  'reclaimedproductsandtheirpackagingmaterialsaspercentageoftotalproductssoldinrespectivecategory': ['Principle 2',
#   'Environment'],
#  'numberofwellbeingofemployeesorworkers': ['Principle 3', 'Social'],
#  'percentageofwellbeingofemployeesorworkers': ['Principle 3', 'Social'],
#  'numberofemployeescoveredasperecentageoftotalemployees': ['Principle 3',
#   'Social'],
#  'numberofemployeescoveredasperecentageoftotalworker': ['Principle 3',
#   'Social'],
#  'deductedanddepositedwiththeauthority': ['Principle 3', 'Social'],
#  'arethepremisesorofficesoftheentityaccessibletodifferentlyabledemployeesandworkers': ['Principle 3',
#   'Social'],
#  'doestheentityhaveanequalopportunitypolicyaspertherightsofpersonswithdisabilitiesact2016': ['Principle 3',
#   'Social'],
#  'weblinkofequaloppertunitypolicytextblock': ['Principle 3', 'Social'],
#  'isthereamechanismavailabletoreceiveandredressgrievancesforthefollowingcategoriesofemployeesandworker': ['Principle 3',
#   'Social'],
#  'isthereamechanismavailabletoreceiveandredressgrievancesforpermanentworkers': ['Principle 3',
#   'Social'],
#  'isthereamechanismavailabletoreceiveandredressgrievancesforotherthanpermanentworkers': ['Principle 3',
#   'Social'],
#  'isthereamechanismavailabletoreceiveandredressgrievancesforpermanentemployees': ['Principle 3',
#   'Social'],
#  'detailsofmechanismavailabletoreceiveandredressgrievancesforpermanentemployeesexplanatorytextblock': ['Principle 3',
#   'Social'],
#  'isthereamechanismavailabletoreceiveandredressgrievancesforotherthanpermanentemployees': ['Principle 3',
#   'Social'],
#  'detailsofmechanismavailabletoreceiveandredressgrievancesforotherthanpermanentemployeesexplanatorytextblock': ['Principle 3',
#   'Social'],
#  'whetheranoccupationalhealthandsafetymanagementsystemhasbeenimplementedbytheentity': ['Principle 3',
#   'Social'],
#  'detailsofoccupationalhealthandsafetymanagementsystemexplanatorytextblock': ['Principle 3',
#   'Social'],
#  'desclosureoftheprocessesusedtoidentifyworkrelatedhazardsandassessrisksonaroutineandnonroutinebasisbytheentityexplanatorytextblock': ['Principle 3',
#   'Social'],
#  'whetheryouhaveprocessesforworkerstoreporttheworkrelatedhazardsandtoremovethemselvesfromsuchrisks': ['Principle 3',
#   'Social'],
#  'dotheemployeesorworkeroftheentityhaveaccesstononoccupationalmedicalandhealthcareservices': ['Principle 3',
#   'Social'],
#  'describethemeasurestakenbytheentitytoensureasafeandhealthyworkplaceexplanatorytextblock': ['Principle 3',
#   'Social'],
#  'detailsofanycorrectiveactiontakenorunderwaytoaddresssafetyrelatedincidentsofyourplantsandofficesthatwereassessedexplanatorytextblock': ['Principle 3',
#   'Social'],
#  'percentageofhealthandsafetypracticesofyourplantsandofficesthatwereassessedp3': ['Principle 3',
#   'Social'],
#  'percentageofworkingconditionsofyourplantsandofficesthatwereassessedp3': ['Principle 3',
#   'Social'],
#  'returntoworkratepermanentemployeesthattookparentalleave': ['Principle 3',
#   'Social'],
#  'retentionratespermanentemployeesthattookparentalleave': ['Principle 3',
#   'Social'],
#  'returntoworkratepermanentworkersthattookparentalleave': ['Principle 3',
#   'Social'],
#  'retentionratespermanentworkersthattookparentalleave': ['Principle 3',
#   'Social'],
#  'totalnumberofemployeesorworkersformembership': ['Principle 3', 'Social'],
#  'numberofemployeesorworkersarepartofassociationsorunion': ['Principle 3',
#   'Social'],
#  'percentageofemployeesorworkersarepartofassociationsorunionoftotalnumberofemployee': ['Principle 3',
#   'Social'],
#  'numberoftrainedemployeesorworkers': ['Principle 3', 'Social'],
#  'percentageoftrainedemployeesorworkers': ['Principle 3', 'Social'],
#  'totalnumberofemployeesorworkersforperformanceandcareerdevelopment': ['Principle 3',
#   'Social'],
#  'numberofemployeesorworkerforperformanceandcareerdevelopment': ['Principle 3',
#   'Social'],
#  'percentageofemployeesorworkerforperformanceandcareerdevelopment': ['Principle 3',
#   'Social'],
#  'losttimeinjuryfrequencyrateperonemillionpersonhoursworked': ['Principle 3',
#   'Social'],
#  'totalrecordableworkrelatedinjuries': ['Principle 3', 'Social'],
#  'numberoffatalities': ['Principle 3', 'Social'],
#  'highconsequenceworkrelatedinjuryorillhealthexcludingfatalities': ['Principle 3',
#   'Social'],
#  'numberofcompliantsfiledduringtheyear': ['Principle 3', 'Social'],
#  'numberofcompliantspendingresolutionattheendofyear': ['Principle 3',
#   'Social'],
#  'doestheentityextendanylifeinsuranceoranycompensatorypackageintheeventofdeathofemployees': ['Principle 3',
#   'Social'],
#  'doestheentityextendanylifeinsuranceoranycompensatorypackageintheeventofdeathofworkers': ['Principle 3',
#   'Social'],
#  'totalnumberofaffectedemployees': ['Principle 3', 'Social'],
#  'numberofemployeesorwhosefamilymembersrehabilitatedandplacedinsuitableemployment': ['Principle 3',
#   'Social'],
#  'totalnumberofaffectedworkers': ['Principle 3', 'Social'],
#  'numberofworkersorwhosefamilymembersrehabilitatedandplacedinsuitableemployment': ['Principle 3',
#   'Social'],
#  'doestheentityprovidetransitionassistanceprogramstofacilitatecontinuedemployabilityandthemanagementofcareerendingsresultingfromretirementorterminationofemployment': ['Principle 3',
#   'Social'],
#  'percentageofhealthandsafetypracticesofvaluechainpartnersp3': ['Principle 4',
#   'Social'],
#  'percentageofworkingconditionsofvaluechainpartnersp3': ['Principle 4',
#   'Social'],
#  'detailsofanycorrectiveactiontakenorunderwaytoaddresssafetyrelatedincidentsonassessmentofvaluechainpartnersexplanatorytextblock': ['Principle 4',
#   'Social'],
#  'describetheprocessesforidentifyingkeystakeholdergroupsoftheentityexplanatorytextblock': ['Principle 4',
#   'Social'],
#  'providetheprocessesforconsultationbetweenstakeholdersandtheboardoneconomicenvironmentalandsocialtopicsorifconsultationisdelegatedhowisfeedbackfromsuchconsultationsprovidedtotheboardexplanatorytextblock': ['Principle 4',
#   'Social'],
#  'whetherstakeholderconsultationisusedtosupporttheidentificationandmanagementofenvironmentalandsocialtopics': ['Principle 4',
#   'Social'],
#  'detailsofinstancesastohowtheinputsreceivedfromstakeholdersonthesetopicswereincorporatedintopoliciesandactivitiesoftheentityexplanatorytextblock': ['Principle 4',
#   'Social'],
#  'detailsofinstancesofengagementwithandactionstakentoaddresstheconcernsofvulnerablemarginalizedstakeholdergroupsexplanatorytextblock': ['Principle 4',
#   'Social'],
#  'stakeholdergroup': ['Principle 4', 'Social'],
#  'whetheridentifiedasvulnerableandmarginalizedgroup': ['Principle 4',
#   'Social'],
#  'channelsofcommunication': ['Principle 4', 'Social'],
#  'frequencyofengagement': ['Principle 4', 'Social'],
#  'purposeandscopeofengagementincludingkeytopicsandconcernsraisedduringsuchengagement': ['Principle 4',
#   'Social'],
#  'totalnumberofemployeesorworkersfortrainingonhumanrightsissues': ['Principle 5',
#   'Social'],
#  'numberofemployeesorworkerscoveredforprovidedtrainingonhumanrightsissues': ['Principle 5',
#   'Social'],
#  'percentageofemployeesorworkerscoveredforprovidedtrainingonhumanrightsissues': ['Principle 5',
#   'Social'],
#  'numberofemployeesorworkersrelatedtominimumwages': ['Principle 5', 'Social'],
#  'percentageofemployeesorworkersrelatedtominimumwages': ['Principle 5',
#   'Social'],
#  'numberofboardofdirectorsforremunerationorsalaryorwages': ['Principle 5',
#   'Social'],
#  'medianofremunerationorsalaryorwagesofboardofdirectors': ['Principle 5',
#   'Social'],
#  'numberofkeymanagerialpersonnelforremunerationorsalaryorwages': ['Principle 5',
#   'Social'],
#  'medianofremunerationorsalaryorwagesofkeymanagerialpersonnel': ['Principle 5',
#   'Social'],
#  'numberofemployeesotherthanbodandkmpforremunerationorsalaryorwages': ['Principle 5',
#   'Social'],
#  'medianofremunerationorsalaryorwagesofemployeesotherthanbodandkmp': ['Principle 5',
#   'Social'],
#  'numberofworkersforremunerationorsalaryorwages': ['Principle 5', 'Social'],
#  'medianofremunerationorsalaryorwagesofworkers': ['Principle 5', 'Social'],
#  'doyouhaveafocalpointresponsibleforaddressinghumanrightsimpactsorissuescausedorcontributedtobythebusiness': ['Principle 5',
#   'Social'],
#  'describetheinternalmechanismsinplacetoredressgrievancesrelatedtohumanrightsissuesexplanatorytextblock': ['Principle 5',
#   'Social'],
#  'remarksforcompliantsexplanatorytextblock': ['Principle 5', 'Social'],
#  'mechanismstopreventadverseconsequencestothecomplainantindiscriminationandharassmentcasesexplanatorytextblock': ['Principle 5',
#   'Social'],
#  'dohumanrightsrequirementsformpartofyourbusinessagreementsandcontracts': ['Principle 5',
#   'Social'],
#  'percentageofchildlabourofyourplantsandofficesthatwereassessedp5': ['Principle 5',
#   'Social'],
#  'percentageofforcedlabourorinvoluntarylabourofyourplantsandofficesthatwereassessedp5': ['Principle 5',
#   'Social'],
#  'percentageofsexualharassmentofyourplantsandofficesthatwereassessedp5': ['Principle 5',
#   'Social'],
#  'percentageofdiscriminationatworkplaceofyourplantsandofficesthatwereassessedp5': ['Principle 5',
#   'Social'],
#  'percentageofwagesofyourplantsandofficesthatwereassessedp5': ['Principle 5',
#   'Social'],
#  'detailsofanycorrectiveactionstakenorunderwaytoaddresssignificantrisksorconcernsarisingfromtheassessmentsofplantandofficeexplanatorytextblock': ['Principle 5',
#   'Social'],
#  'detailsofabusinessprocessbeingmodifiedorintroducedasaresultofaddressinghumanrightsgrievancesorcomplaintsexplanatorytextblock': ['Principle 5',
#   'Social'],
#  'detailsofthescopeandcoverageofanyhumanrightsduediligenceconductedexplanatorytextblock': ['Principle 5',
#   'Social'],
#  'isthepremiseorofficeoftheentityaccessibletodifferentlyabledvisitorsaspertherequirementsoftherightsofpersonswithdisabilitiesact2016': ['Principle 5',
#   'Social'],
#  'percentageofsexualharassmentofvaluechainpartnersp5': ['Principle 5',
#   'Social'],
#  'percentageofdiscriminationatworkplaceofvaluechainpartnersp5': ['Principle 5',
#   'Social'],
#  'percentageofchildlabourofvaluechainpartnersp5': ['Principle 5', 'Social'],
#  'percentageofforcedlabourorinvoluntarylabourofvaluechainpartnersp5': ['Principle 5',
#   'Social'],
#  'percentageofwagesofvaluechainpartnersp5': ['Principle 5', 'Social'],
#  'totalelectricityconsumption': ['Principle 6', 'Environment'],
#  'totalfuelconsumption': ['Principle 6', 'Environment'],
#  'energyconsumptionthroughothersources': ['Principle 6', 'Environment'],
#  'totalenergyconsumption': ['Principle 6', 'Environment'],
#  'energyintensityperrupeeofturnover': ['Principle 6', 'Environment'],
#  'energyintensitytherelevantmetricmaybeselectedbytheentity': ['Principle 6',
#   'Environment'],
#  'anyindependentassessmentorevaluationorassurancehasbeencarriedoutbyanexternalagencyforenergyconsumption': ['Principle 6',
#   'Environment'],
#  'doestheentityhaveanysitesorfacilitiesidentifiedasdesignatedconsumersundertheperformanceachieveandtradeschemeofthegovernmentofindia': ['Principle 6',
#   'Environment'],
#  'waterwithdrawalbysurfacewater': ['Principle 6', 'Environment'],
#  'waterwithdrawalbygroundwater': ['Principle 6', 'Environment'],
#  'waterwithdrawalbythirdpartywater': ['Principle 6', 'Environment'],
#  'waterwithdrawalbyseawaterordesalinatedwater': ['Principle 6', 'Environment'],
#  'waterwithdrawalbyothers': ['Principle 6', 'Environment'],
#  'totalvolumeofwaterwithdrawal': ['Principle 6', 'Environment'],
#  'totalvolumeofwaterconsumption': ['Principle 6', 'Environment'],
#  'waterintensityperrupeeofturnover': ['Principle 6', 'Environment'],
#  'waterintensitytherelevantmetricmaybeselectedbytheentity': ['Principle 6',
#   'Environment'],
#  'anyindependentassessmentorevaluationorassurancehasbeencarriedoutbyanexternalagencyforwaterwithdrawal': ['Principle 6',
#   'Environment'],
#  'hastheentityimplementedamechanismforzeroliquiddischarge': ['Principle 6',
#   'Environment'],
#  'unitofnox': ['Principle 6', 'Environment'],
#  'nox': ['Principle 6', 'Environment'],
#  'unitofsox': ['Principle 6', 'Environment'],
#  'sox': ['Principle 6', 'Environment'],
#  'unitofparticulatematter': ['Principle 6', 'Environment'],
#  'particulatematter': ['Principle 6', 'Environment'],
#  'unitofpersistentorganicpollutants': ['Principle 6', 'Environment'],
#  'persistentorganicpollutants': ['Principle 6', 'Environment'],
#  'unitofvolatileorganiccompounds': ['Principle 6', 'Environment'],
#  'volatileorganiccompounds': ['Principle 6', 'Environment'],
#  'unitofhazardousairpollutants': ['Principle 6', 'Environment'],
#  'hazardousairpollutants': ['Principle 6', 'Environment'],
#  'indicateifanyindependentassessmentorevaluationorassurancehasbeencarriedoutbyanexternalagencyforairemissionsotherthanghgemissions': ['Principle 6',
#   'Environment'],
#  'unitoftotalscope1emissions': ['Principle 6', 'Environment'],
#  'totalscope1emissions': ['Principle 6', 'Environment'],
#  'unitoftotalscope2emissions': ['Principle 6', 'Environment'],
#  'totalscope2emissions': ['Principle 6', 'Environment'],
#  'unitoftotalscope1andscope2emissionsperrupeeofturnover': ['Principle 6',
#   'Environment'],
#  'totalscope1andscope2emissionsperrupeeofturnover': ['Principle 6',
#   'Environment'],
#  'unitoftotalscope1andscope2emissionintensity': ['Principle 6', 'Environment'],
#  'totalscope1andscope2emissionintensity': ['Principle 6', 'Environment'],
#  'whetheranyindicateifanyindependentassessmentorevaluationorassurancehasbeencarriedoutbyanexternalagencyforgreenhousegasemissions': ['Principle 6',
#   'Environment'],
#  'doestheentityhaveanyprojectrelatedtoreducinggreenhousegasemission': ['Principle 6',
#   'Environment'],
#  'detailsofprojectrelatedtoreducinggreenhousegasemissionexplanatorytextblock': ['Principle 6',
#   'Environment'],
#  'plasticwaste': ['Principle 6', 'Environment'],
#  'ewaste': ['Principle 6', 'Environment'],
#  'biomedicalwaste': ['Principle 6', 'Environment'],
#  'constructionanddemolitionwaste': ['Principle 6', 'Environment'],
#  'batterywaste': ['Principle 6', 'Environment'],
#  'radioactivewaste': ['Principle 6', 'Environment'],
#  'otherhazardouswaste': ['Principle 6', 'Environment'],
#  'othernonhazardouswastegenerated': ['Principle 6', 'Environment'],
#  'totalwastegenerated': ['Principle 6', 'Environment'],
#  'wasterecoveredthroughrecycled': ['Principle 6', 'Environment'],
#  'wasterecoveredthroughreused': ['Principle 6', 'Environment'],
#  'wasterecoveredthroughotherrecoveryoperations': ['Principle 6',
#   'Environment'],
#  'totalwasterecovered': ['Principle 6', 'Environment'],
#  'wastedisposedbyincineration': ['Principle 6', 'Environment'],
#  'wastedisposedbylandfilling': ['Principle 6', 'Environment'],
#  'wastedisposedbyotherdisposaloperations': ['Principle 6', 'Environment'],
#  'totalwastedisposed': ['Principle 6', 'Environment'],
#  'whetheranyindependentassessmentorevaluationorassurancehasbeencarriedoutbyanexternalagencyforwastemanagement': ['Principle 6',
#   'Environment'],
#  'detailsofwastemanagementpracticesadoptedinyourestablishmentsandthestrategyadoptedbycompanytoreduceusageofhazardousandtoxicchemicalsexplanatorytextblock': ['Principle 6',
#   'Environment'],
#  'locationofoperationsoroffices': ['Principle 6', 'Environment'],
#  'typeofoperations': ['Principle 6', 'Environment'],
#  'whethertheconditionsofenvironmentalapprovalorclearancearebeingcompliedwith': ['Principle 6',
#   'Environment'],
#  'reasonsandcorrectiveactiontakeniftheconditionsofenvironmentalapprovalorclearancearenotbeingcompliedwith': ['Principle 6',
#   'Environment'],
#  'istheentitycompliantwiththeapplicableenvironmentallaw': ['Principle 6',
#   'Environment'],
#  'totalelectricityconsumptionfromrenewablesources': ['Principle 6',
#   'Environment'],
#  'totalfuelconsumptionfromrenewablesources': ['Principle 6', 'Environment'],
#  'energyconsumptionthroughothersourcesfromrenewablesources': ['Principle 6',
#   'Environment'],
#  'totalenergyconsumedfromrenewablesources': ['Principle 6', 'Environment'],
#  'totalelectricityconsumptionfromnonrenewablesources': ['Principle 6',
#   'Environment'],
#  'totalfuelconsumptionfromnonrenewablesources': ['Principle 6', 'Environment'],
#  'energyconsumptionthroughothersourcesfromnonrenewablesources': ['Principle 6',
#   'Environment'],
#  'totalenergyconsumedfromnonrenewablesources': ['Principle 6', 'Environment'],
#  'whetheranyindependentassessmentorevaluationorassurancehasbeencarriedoutbyanexternalagencyforenergyconsumptionunderleadershipindicators': ['Principle 6',
#   'Environment'],
#  'waterdischargetosurfacewater': ['Principle 6', 'Environment'],
#  'waterdischargetosurfacewaterwithouttreatment': ['Principle 6',
#   'Environment'],
#  'waterdischargetosurfacewaterwithtreatment': ['Principle 6', 'Environment'],
#  'waterdischargetogroundwater': ['Principle 6', 'Environment'],
#  'waterdischargetogroundwaterwithouttreatment': ['Principle 6', 'Environment'],
#  'waterdischargetogroundwaterwithtreatment': ['Principle 6', 'Environment'],
#  'waterdischargetoseawater': ['Principle 6', 'Environment'],
#  'waterdischargetoseawaterwithouttreatment': ['Principle 6', 'Environment'],
#  'waterdischargetoseawaterwithtreatment': ['Principle 6', 'Environment'],
#  'waterdischargebysenttothirdparties': ['Principle 6', 'Environment'],
#  'waterdischargebysenttothirdpartieswithouttreatment': ['Principle 6',
#   'Environment'],
#  'waterdischargebysenttothirdpartieswithtreatment': ['Principle 6',
#   'Environment'],
#  'waterdischargetoothers': ['Principle 6', 'Environment'],
#  'waterdischargetootherswithouttreatment': ['Principle 6', 'Environment'],
#  'waterdischargetootherswithtreatment': ['Principle 6', 'Environment'],
#  'totalwaterdischargedinkilolitres': ['Principle 6', 'Environment'],
#  'whetheranyindependentassessmentorevaluationorassurancehasbeencarriedoutbyanexternalagencyforwaterdischarged': ['Principle 6',
#   'Environment'],
#  'indicateifanyindependentassessmentorevaluationorassurancehasbeencarriedoutbyanexternalagencyforareasofwaterstress': ['Principle 6',
#   'Environment'],
#  'unitoftotalscope3emissions': ['Principle 6', 'Environment'],
#  'totalscope3emissions': ['Principle 6', 'Environment'],
#  'unitoftotalscope3emissionsperrupeeofturnover': ['Principle 6',
#   'Environment'],
#  'totalscope3emissionsperrupeeofturnover': ['Principle 6', 'Environment'],
#  'unitoftotalscope3emissionintensity': ['Principle 6', 'Environment'],
#  'totalscope3emissionintensity': ['Principle 6', 'Environment'],
#  'whetheranyindependentassessmentorevaluationorassurancehasbeencarriedoutbyanexternalagencyfortotalscope3emissions': ['Principle 6',
#   'Environment'],
#  'detailsofsignificantdirectandindirectimpactoftheentityonbiodiversityinsuchareasalongwithpreventionandremediationactivitiesexplanatorytextblock': ['Principle 6',
#   'Environment'],
#  'doestheentityhaveabusinesscontinuityanddisastermanagementplan': ['Principle 6',
#   'Environment'],
#  'disclosureweblinkofentityatwhichbusinesscontinuityanddisastermanagementplanisplaced': ['Principle 6',
#   'Environment'],
#  'discloseanysignificantadverseimpacttotheenvironmentarisingfromthevaluechainoftheentitywhatmitigationoradaptationmeasureshavebeentakenbytheentityinthisregardexplanatorytextblock': ['Principle 6',
#   'Environment'],
#  'percentageofvaluechainpartnersbyvalueofbusinessdonewithsuchpartnersthatwereassessedforenvironmentalimpacts': ['Principle 6',
#   'Environment'],
#  'initiativeundertaken': ['Principle 6', 'Environment'],
#  'weblinkfordetailsofintiativetakenbyentity': ['Principle 6', 'Environment'],
#  'outcomeoftheinitiative': ['Principle 6', 'Environment'],
#  'correctiveactiontakenforinitiative': ['Principle 6', 'Environment'],
#  'nameofthearea': ['Principle 6', 'Environment'],
#  'natureofoperations': ['Principle 6', 'Environment'],
#  'waterwithdrawalbysurfacewaterperarea': ['Principle 6', 'Environment'],
#  'waterwithdrawalbygroundwaterperarea': ['Principle 6', 'Environment'],
#  'waterwithdrawalbythirdpartywaterperarea': ['Principle 6', 'Environment'],
#  'waterwithdrawalbyseawaterordesalinatedwaterperarea': ['Principle 6',
#   'Environment'],
#  'waterwithdrawalbyothersperarea': ['Principle 6', 'Environment'],
#  'totalvolumeofwaterwithdrawalperarea': ['Principle 6', 'Environment'],
#  'totalvolumeofwaterconsumptionperarea': ['Principle 6', 'Environment'],
#  'waterintensityperrupeeofturnoverperarea': ['Principle 6', 'Environment'],
#  'waterintensity': ['Principle 6', 'Environment'],
#  'waterdischargetosurfacewaterperarea': ['Principle 6', 'Environment'],
#  'waterdischargetosurfacewaterwithouttreatmentperarea': ['Principle 6',
#   'Environment'],
#  'waterdischargetosurfacewaterwithtreatmentperarea': ['Principle 6',
#   'Environment'],
#  'waterdischargetogroundwaterperarea': ['Principle 6', 'Environment'],
#  'waterdischargetogroundwaterwithouttreatmentperarea': ['Principle 6',
#   'Environment'],
#  'waterdischargetogroundwaterwithtreatmentperarea': ['Principle 6',
#   'Environment'],
#  'waterdischargetoseawaterperarea': ['Principle 6', 'Environment'],
#  'waterdischargetoseawaterwithouttreatmentperarea': ['Principle 6',
#   'Environment'],
#  'waterdischargetoseawaterwithtreatmentperarea': ['Principle 6',
#   'Environment'],
#  'waterdischargebysenttothirdpartiesperarea': ['Principle 6', 'Environment'],
#  'waterdischargebysenttothirdpartieswithouttreatmentperarea': ['Principle 6',
#   'Environment'],
#  'waterdischargebysenttothirdpartieswithtreatmentperarea': ['Principle 6',
#   'Environment'],
#  'waterdischargetoothersperarea': ['Principle 6', 'Environment'],
#  'waterdischargetootherswithouttreatmentperarea': ['Principle 6',
#   'Environment'],
#  'waterdischargetootherswithtreatmentperarea': ['Principle 6', 'Environment'],
#  'totalwaterdischargedinkilolitresperarea': ['Principle 6', 'Environment'],
#  'numberofaffiliationswithtradeandindustrychambersorassociations': ['Principle 7',
#   'Governance'],
#  'nameofthetradeandindustrychambersorassociations': ['Principle 7',
#   'Governance'],
#  'reachoftradeandindustrychambersorassociations': ['Principle 7',
#   'Governance'],
#  'nameofauthority': ['Principle 7', 'Governance'],
#  'briefofanyissuesrelatedtoanticompetitiveconductbytheentity': ['Principle 7',
#   'Governance'],
#  'correctiveactiontakenforanyissuesrelatedtoanticompetitiveconductbytheentity': ['Principle 7',
#   'Governance'],
#  'publicpolicyadvocated': ['Principle 7', 'Governance'],
#  'methodresortedforsuchadvocacy': ['Principle 7', 'Governance'],
#  'whetherinformationavailableinpublicdomain': ['Principle 7', 'Governance'],
#  'frequencyofreviewbyboard': ['Principle 7', 'Governance'],
#  'weblinkpublicpolicypositionadvocated': ['Principle 7', 'Governance'],
#  'describethemechanismstoreceiveandredressgrievancesofthecommunityexplanatorytextblock': ['Principle 7',
#   'Governance'],
#  'percentageofdirectlysourcedfrommsmesorsmallproducers': ['Principle 7',
#   'Governance'],
#  'percentageofsourceddirectlyfromwithinthedistrictandneighbouringdistricts': ['Principle 7',
#   'Governance'],
#  'intellectualpropertybasedontraditionalknowledge': ['Principle 8',
#   'Governance'],
#  'ownedoracquired': ['Principle 8', 'Governance'],
#  'benefitshared': ['Principle 8', 'Governance'],
#  'basisofcalculatingbenefitshare': ['Principle 8', 'Governance'],
#  'nameofauthorityforintellectualpropertyrelateddisputes': ['Principle 8',
#   'Governance'],
#  'briefofthecaseforintellectualpropertyrelateddisputes': ['Principle 8',
#   'Governance'],
#  'correctiveactiontakenforintellectualpropertyrelateddisputes': ['Principle 8',
#   'Governance'],
#  'csrproject': ['Principle 8', 'Governance'],
#  'numberofpersonsbenefittedfromcsrprojects': ['Principle 8', 'Governance'],
#  'percentageofbeneficiariesfromvulnerableandmarginalizedgroups': ['Principle 8',
#   'Governance'],
#  'detailsofnegativesocialimpactidentified': ['Principle 8', 'Governance'],
#  'correctiveactiontakenfornegativesocialimpactidentified': ['Principle 8',
#   'Governance'],
#  'stateofcsrprojectsundertaken': ['Principle 8', 'Governance'],
#  'aspirationaldistrictofcsrprojectsundertaken': ['Principle 8', 'Governance'],
#  'amountspentforcsrprojectsundertaken': ['Principle 8', 'Governance'],
#  'doyouhaveapreferentialprocurementpolicywhereyougivepreferencetopurchasefromsupplierscomprisingmarginalizedorvulnerablegroups': ['Principle 8',
#   'Governance'],
#  'fromwhichmarginalizedorvulnerablegroupsdoyouprocure': ['Principle 8',
#   'Governance'],
#  'whatpercentageoftotalprocurementbyvaluedoesitconstitute': ['Principle 8',
#   'Governance'],
#  'describethemechanismsinplacetoreceiveandrespondtoconsumercomplaintsandfeedbackexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'environmentalandsocialparametersrelevanttotheproductasapercentagetototalturnover': ['Principle 8',
#   'Governance'],
#  'safeandresponsibleusageasapercentagetototalturnover': ['Principle 8',
#   'Governance'],
#  'recyclingandorsafedisposalasapercentagetototalturnover': ['Principle 8',
#   'Governance'],
#  'consumercomplaintsreceivedduringtheyear': ['Principle 8', 'Governance'],
#  'consumercomplaintspendingresolutionatendofyear': ['Principle 8',
#   'Governance'],
#  'remarkforconsumercomplaints': ['Principle 8', 'Governance'],
#  'numberofvoluntaryrecalls': ['Principle 8', 'Governance'],
#  'reasonsforvoluntaryrecall': ['Principle 8', 'Governance'],
#  'numberofforcedrecalls': ['Principle 8', 'Governance'],
#  'reasonsforforcedrecall': ['Principle 8', 'Governance'],
#  'doestheentityhaveaframeworkorpolicyoncybersecurityandrisksrelatedtodataprivacy': ['Principle 8',
#   'Governance'],
#  'weblinkofthepolicyoncybersecurityandrisksrelatedtodataprivacy': ['Principle 8',
#   'Governance'],
#  'detailsofanycorrectiveactionstakenorunderwayonissuesrelatingtoadvertisinganddeliveryofessentialservicesorcybersecurityanddataprivacyorrecallsorpenaltyoractiontakenbyregulatoryauthoritiesonsafetyofproductsorservicesexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'weblinkwhereinformationonproductsandservicesoftheentitycanbeaccessedexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'stepstakentoinformandeducateconsumersaboutsafeandresponsibleusageofproductsandorservicesexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'mechanismsinplacetoinformconsumersofanyriskofdisruptionordiscontinuationofessentialservicesexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'doestheentitydisplayproductinformationontheproductoverandabovewhatismandatedasperlocallaws': ['Principle 8',
#   'Governance'],
#  'detailsofproductinformationontheproductoverandabovewhatismandatedasperlocallawsexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'didyourentitycarryoutanysurveywithregardtoconsumersatisfactionrelatingtothemajorproductsorservicesoftheentitysignificantlocationsofoperationoftheentityortheentityasawhole': ['Principle 8',
#   'Governance'],
#  'numberofinstancesofdatabreachesalongwithimpact': ['Principle 8',
#   'Governance'],
#  'percentageofdatabreachesinvolvingpersonallyidentifiableinformationofcustomers': ['Principle 8',
#   'Governance'],
#  'nameofprojectforwhichrehabilitationandresettlementisongoing': ['Principle 8',
#   'Governance'],
#  'stateofproject': ['Principle 8', 'Governance'],
#  'districtofproject': ['Principle 8', 'Governance'],
#  'numberofprojectaffectedfamilies': ['Principle 8', 'Governance'],
#  'percentageofpafscoveredbyrehabilitationandresettlement': ['Principle 8',
#   'Governance'],
#  'amountspaidtopafs': ['Principle 8', 'Governance'],
#  'percentageofinputsweresourcedsustainably': ['Principle 8', 'Governance'],
#  'nameofotherretirementbenefits': ['Principle 8', 'Governance'],
#  'nameofotherassessmentsofplantandoffice': ['Principle 8', 'Governance'],
#  'percentageofotherassessmentsofplantandoffice': ['Principle 8', 'Governance'],
#  'nameoftheexternalagencyifanyindependentassessmentorevaluationorassurancehasbeencarriedoutbyanexternalagencyforenergyconsumptionexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'nameoftheexternalagencyincaseanyindependentassessmentorevaluationorassurancehasbeencarriedoutbyanexternalagencyforwaterwithdrawalexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'detailsofcoverageandimplementationifforzeroliquiddischargeexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'nameoftheexternalagencythatundertookindependentassessmentorevaluationorassuranceforgreenhousegasemissionsexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'nameoftheexternalagencythatundertookindependentassessmentorevaluationorassurancerelatedtowastemanagementexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'nameandbriefdetailsofproject': ['Principle 8', 'Governance'],
#  'eianotificationnumber': ['Principle 8', 'Governance'],
#  'dateofenvironmentalimpactassessments': ['Principle 8', 'Governance'],
#  'whetherconductedbyindependentexternalagencyp6': ['Principle 8',
#   'Governance'],
#  'resultscommunicatedinpublicdomainp6': ['Principle 8', 'Governance'],
#  'weblinkofresultsoflifecycleassessmentsp6': ['Principle 8', 'Governance'],
#  'nameoftheexternalagencythatundertookindependentassessmentorevaluationorassuranceforenergyconsumptionexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'nameoftheexternalagencythatundertookindependentassessmentorevaluationorassuranceforwaterdischargedexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'nameoftheexternalagencyifanyindependentassessmentorevaluationorassurancehasbeencarriedoutbyanexternalagencyforareasofwaterstressexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'nameoftheexternalagencythatundertookindependentassessmentorevaluationorassurancefortotalscope3emissionsexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'nameofotherparameterofenergyconsumptionthroughothersourcefromrenewablesources': ['Principle 8',
#   'Governance'],
#  'nameandbriefdetailsofprojectsia': ['Principle 8', 'Governance'],
#  'sianotificationnumber': ['Principle 8', 'Governance'],
#  'dateofnotification': ['Principle 8', 'Governance'],
#  'whetherconductedbyindependentexternalagencyforsia': ['Principle 8',
#   'Governance'],
#  'resultscommunicatedinpublicdomainofsia': ['Principle 8', 'Governance'],
#  'weblinkofsiaofprojects': ['Principle 8', 'Governance'],
#  'nameofstakeholdergroup': ['Principle 8', 'Governance'],
#  'nameofotherwast': ['Principle 8', 'Governance'],
#  'detailsofmechanismavailabletoreceiveandredressgrievancesforpermanentworkersexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'detailsofmechanismavailabletoreceiveandredressgrievancesforotherthanpermanentworkersexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'nameoftheexternalagencyifanyindependentassessmentorevaluationorassurancehasbeencarriedoutbyanexternalagencyforairemissionsotherthanghgemissionsexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'niccodeofproductorserviceofconductedlifecycleperspective': ['Principle 8',
#   'Governance'],
#  'nameofproductorserviceofconductedlifecycleperspective': ['Principle 8',
#   'Governance'],
#  'percentageoftotalturnovercontributedforconductedlifecycleperspective': ['Principle 8',
#   'Governance'],
#  'boundaryforwhichthelifecycleperspectiveorassessmentwasconducted': ['Principle 8',
#   'Governance'],
#  'whetherconductedbyindependentexternalagency': ['Principle 8', 'Governance'],
#  'resultscommunicatedinpublicdomain': ['Principle 8', 'Governance'],
#  'disclosewhethertargetssetunderthepatschemehavebeenachievedincasetargetshavenotbeenachievedthenprovidetheremedialactiontakenexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'nameofotherparameterofenergyconsumptionthroughothersourcefromnonrenewablesources': ['Principle 8',
#   'Governance'],
#  'nameordetailsofthelaworregulationorguidelineswhichwasnotcompliedwith': ['Principle 8',
#   'Governance'],
#  'providedetailsofthenoncompliance': ['Principle 8', 'Governance'],
#  'anyfinesorpenaltiesoractiontakenbyregulatoryagenciessuchaspollutioncontrolboardsorbycourts': ['Principle 8',
#   'Governance'],
#  'correctiveactiontakenfornoncompliance': ['Principle 8', 'Governance'],
#  'weblinkofresultsoflifecycleassessments': ['Principle 8', 'Governance'],
#  'whetheranystepsarebeingtakenbytheentityifthepremisesorofficesoftheentitynotaccessibletodifferentlyabledemployeesandworkersexplanatorytextblock': ['Principle 8',
#   'Governance'],
#  'nameofotherassessmentofvaluechainpartner': ['Principle 8', 'Governance'],
#  'percentageofotherassessmentofvaluechainpartner': ['Principle 8',
#   'Governance'],
#  'theentitydoesnotconsidertheprinciplesmaterialtoitsbusiness': ['Principle 9',
#   'Governance'],
#  'theentityisnotatastagewhereitisinapositiontoformulateandimplementthepoliciesonspecifiedprinciples': ['Principle 9',
#   'Governance'],
#  'nameofotheremissions': ['Principle 9', 'Governance'],
#  'unitofotheremissions': ['Principle 9', 'Governance'],
#  'otheremissions': ['Principle 9', 'Governance'],
#  'theentitydoesnothavethefinancialorhumanandtechnicalresourcesavailableforthetask': ['Principle 9',
#   'Governance'],
#  'itisplannedtobedoneinthenextfinancialyear': ['Principle 9', 'Governance'],
#  'anyotherreasonsifpoliciesnotcovereachprincipleanditscoreelementsofthengrbcsexplanatorytextblock': ['Principle 9',
#   'Governance'],
#  'scripcode': ['Principle 9', 'Governance'],
#  'nsesymbol': ['Principle 9', 'Governance'],
#  'mseisymbol': ['Principle 9', 'Governance'],
#  'reportingperiod': ['Principle 9', 'Governance'],
#  'dateofstartofreportingperiod': ['Principle 9', 'Governance'],
#  'dateofendofreportingperiod': ['Principle 9', 'Governance'],
#  'levelofroundingusedinfinancialstatements': ['Principle 9', 'Governance'],
#  'whetherthecompanyhasanyrelatedparty': ['Principle 9', 'Governance'],
#  'whetherthecompanyhasenteredintoanyrelatedpartytransactionduringtheperiod': ['Principle 9',
#   'Governance'],
#  'wedeclarethattheacceptanceoffixeddepositsbythebansornonbankingfinancecompanyareatthetermsuniformlyapplicableorofferedtoallshareholdersorpublic': ['Principle 9',
#   'Governance'],
#  'wedeclarethatthescheduledcommercialbankasperrbicircularrbidbr20151619datedmarch032016hasallowedadditionalinterestofonepercentperannumoverandabovetherateofinterestmentionedinthescheduleofinterestratesonsavings': ['Principle 9',
#   'Governance'],
#  'whetherthecompanyisahighvaluedebtlistedentityaccordingtoregulation151a': ['Principle 9',
#   'Governance'],
#  'ifthecompanyisahighvaluedebtlistedentityaccordingtoregulation151athenwhethercomplyingwithprovisotoregulation239': ['Principle 9',
#   'Governance'],
#  'nameoflistedentityorsubsidiaryenteringintothetransaction': ['Principle 9',
#   'Governance'],
#  'panoflistedentityorsubsidiaryenteringintothetransaction': ['Principle 9',
#   'Governance'],
#  'nameofcounterparty': ['Principle 9', 'Governance'],
#  'panofcounterparty': ['Principle 9', 'Governance'],
#  'relationshipofthecounterpartywiththelistedentityoritssubsidiary': ['Principle 9',
#   'Governance'],
#  'typeofrelatedpartytransaction': ['Principle 9', 'Governance'],
#  'valueoftherelatedpartytransactionasapprovedbytheauditcommittee': ['Principle 9',
#   'Governance'],
#  'remarksonapprovalbyauditcommittee': ['Principle 9', 'Governance'],
#  'amountofrelatedpartytransactionduringthereportingperiod': ['Principle 9',
#   'Governance'],
#  'amountofrelatedpartytransaction': ['Principle 9', 'Governance'],
#  'detailsofotherrelatedpartytransaction': ['Principle 9', 'Governance'],
#  'relatedpartytransactionexplanatory': ['Principle 9', 'Governance']}

# %% [markdown]
# ## Adding principles column and  esg_category in all 169 files

# %%
# Accessing each xbrl file and adding Principle and esg_category column and labeling them according to the standard unique questions
path = r"C:\Users\Dell\Desktop\esg xbrl files copy"   # Path to the xbrl file folder

directory = pathlib.Path(path)
txt_files = directory.glob("*.xlsx") 
i=0
for file in txt_files:
    df = pd.read_excel(file)
    df["Principles"] = df["Element Name"].str.lower().apply(lambda x: dc_ques_category[x][0] if x in dc_ques_category.keys() else np.nan)
    df["esg_category"] = df["Element Name"].str.lower().apply(lambda x: dc_ques_category[x][1] if x in dc_ques_category.keys() else np.nan)
    df.to_excel(file, index=False)  # Saving the modified xbrl's

# %% [markdown]
# ## bunch of files

# %%
path = r"C:\Users\Dell\Desktop\esg xbrl files copy"
directory = pathlib.Path(path)
file_path = directory.glob("*.xlsx")

# Function to calculate ESG SCORE
def esg_score(category):
    """
    Calculate the ESG (Environmental, Social, and Governance) score for a given category.

    Args:
        category (str): The category for which the ESG score is calculated.
        Select Category from : ["Environment", "Social", "Governance"]

    Returns:
        float: The calculated ESG score for the specified category, ranging between 0 and 1.
    """
    total = len(df[df.esg_category==category].Score)       # total questions of a category
    sum_of_1 = df[df.esg_category==category].Score.sum()   # count of 1's in score column from the total questions of particular category
    score = round(sum_of_1/total, 3)                       # score will be between 0 and 1.
    return score

# The final dataframe that has company identification no.(CIN), company name, E,S,G SCORE
final_df = pd.DataFrame(columns=["CIN", "COMPANY_NAME", "E_SCORE", "S_SCORE", "G_SCORE"])   

for file in file_path:
    df = pd.read_excel(file)
    
    # Calculating E,S,G SCORE for each class
    E_score = esg_score("Environment")
    S_score = esg_score("Social")
    G_score = esg_score("Governance")
    
    try:
        cin = df[df["Element Name"]=="CorporateIdentityNumber"]["Fact Value"][0] # Extracting CIN
    except Exception:
        cin = np.nan
        print(file)
    try:
        company_name = df[df["Element Name"]=="NameOfTheCompany"]["Fact Value"][1] # Extracting Company Name
    except:
        company_name = np.nan
    
    # Appending data for one company at a time in the final df
    data_dc = {"CIN":cin, "COMPANY_NAME":company_name, "E_SCORE":E_score, "S_SCORE":S_score, "G_SCORE":G_score}
    final_df.loc[len(final_df)] = data_dc
final_df
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9284\1473635309.py:19: RuntimeWarning: invalid value encountered in longlong_scalars
#   score = round(sum_of_1/total, 3)                       # score will be between 0 and 1.
# C:\Users\Dell\Desktop\esg xbrl files copy\br_rallis_2021_2022_20220800055.xlsx
#                        CIN                                       COMPANY_NAME
# 0    L31300KA1987PLC013543                                   3M INDIA LIMITED  \
# 1    L65922RJ2011PLC034297                           Aavas Financiers Limited
# 2    L32202KA1949PLC032923                                  ABB INDIA LIMITED
# 3    L51100GJ1993PLC019067   Adani Enterprises Limited (“AEL or the Company”)
# 4    L40106GJ2015PLC082007                         Adani Green Energy Limited
# ..                     ...                                                ...
# 164  L29150TG1930PLC000576                             VST INDUSTRIES LIMITED
# 165  L27100GJ1995PLC025609                               WELSPUN CORP LIMITED
# 166  L17110GJ1985PLC033271                              Welspun India Limited
# 167  L32102KA1945PLC020800                                      Wipro Limited
# 168  L34103TN2004PLC054667  ZF COMMERCIAL VEHICLE CONTROL SYSTEMS INDIA LI...
#
#      E_SCORE  S_SCORE  G_SCORE
# 0      0.215    0.133    0.520
# 1      0.170    0.317    0.253
# 2      0.581    0.484    0.591
# 3      0.583    0.493    0.613
# 4      0.287    0.272    0.530
# ..       ...      ...      ...
# 164    0.443    0.383    0.436
# 165    0.386    0.415    0.566
# 166    0.413    0.393    0.451
# 167    0.385    0.341    0.747
# 168    0.434    0.472    0.577
#
# [169 rows x 5 columns]

# %% [markdown]
# def esg_score(category):
#     total = len(df[df.esg_category==category].Score)
#     sum_of_1 = df[df.esg_category==category].Score.sum()
#     score = round(sum_of_1/total, 3)
#     return score
#
# E_score = esg_score("Environment")
# S_score = esg_score("Social")
# G_score = esg_score("Governance")
# print(E_score, S_score, G_score)
#
# #cin and company name
# cin = df[df["Element Name"]=="CorporateIdentityNumber"]["Fact Value"][0]
#
# company_name = df[df["Element Name"]=="NameOfTheCompany"]["Fact Value"][1]

# %% [markdown]
# final_df = pd.DataFrame(columns=["CIN", "COMPANY_NAME", "E_SCORE", "S_SCORE", "G_SCORE"])
#
# test_dc = {"CIN":"cin123", "COMPANY_NAME":"Tata", "E_SCORE":1, "S_SCORE":2, "G_SCORE":3}
#
# final_df.loc[len(final_df)] = test_dc

# %%
final_df.to_excel(r"C:\Users\Dell\Desktop\esg_score.xlsx", index=False)
